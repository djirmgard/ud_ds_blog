# %% [markdown]
# ## 0) Import libraries

# %%
import pandas as pd
import numpy as np
from datetime import datetime as dt

import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.ticker import PercentFormatter

from statsmodels.regression.linear_model import OLS
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %% [markdown]
# ## 1) Trend of Airbnb listings and visitors

# %% [markdown]
# To see how the Airbnb market in Seattle grew over time, we can count the number of new listings per month. In addition, we can approximated the number of visitors per month and its trend by using the number of reviews of guests.

# %%
#Import datasets
listings=pd.read_csv('listings.csv')
reviews=pd.read_csv('reviews.csv')

# %%
#Convert review date to datetime and extract month/month-year
reviews['date']=pd.to_datetime(reviews['date'])
reviews['month']=reviews['date'].dt.month
reviews['month-year']=reviews['date'].dt.strftime('%Y-%m')

# %%
#Convert first review date of lisiting to datetime and extract month/month-year
listings['first_review']=pd.to_datetime(listings['first_review'])
listings_clean=listings.dropna(subset=['first_review']).copy()
listings_clean['month_first_review']=listings_clean['first_review'].dt.strftime('%Y-%m')

# %%
#Group number of new listings and reviews by month and store as timeseries
data1=listings_clean[listings_clean['first_review']<'2016'].groupby('month_first_review').agg('count')
data2=reviews[reviews['date']<'2016'].groupby('month-year').agg('count')

# %%
#Plot timeseries
fig, ax1 = plt.subplots(figsize=(16,8))

years = mdates.YearLocator()   #every year
months = mdates.MonthLocator()  #every month
years_fmt = mdates.DateFormatter('%Y')

#plot new listings ts
color = 'tab:blue'
line1=ax1.plot(pd.to_datetime(data1.index), data1['id'], color=color, label='new listings (left)')

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

#plot new reviews/visitors ts
color = 'tab:red'
line2=ax2.plot(pd.to_datetime(data2.index), data2['reviewer_id'], color=color, label='visitors')

# format the ticks
ax1.xaxis.set_major_locator(years)
ax1.xaxis.set_major_formatter(years_fmt)
ax1.xaxis.set_minor_locator(months)

# format the coords message box
ax1.format_xdata = mdates.DateFormatter('%Y-%m-%d')

#format axis
ax1.set_xlabel('month')
ax1.set_ylabel('no of new listings')
ax2.set_ylabel('no of visitors')

#format legend
lns = line1+line2
labs = [l.get_label() for l in lns]
ax1.legend(lns, labs, loc=0)

fig.tight_layout()
plt.title('Development of Airbnb listings and visitors in Seattle')
plt.savefig('01_listings_visitors_trend.jpg',dpi=100)
plt.show()

# %% [markdown]
# ## 2) Seasonality of price and availability

# %% [markdown]
# We want to see if the price and availability of a listing varies with the calendar month. We can look at average prices and availability of listings by month using the calendar dataset.

# %%
#Import dataset
calendar=pd.read_csv('calendar.csv')

# %%
#Convert review date to datetime and extract month
calendar['date']=pd.to_datetime(calendar['date'])
calendar['month']=calendar['date'].dt.month

# %%
#Convert availability and price to numeric
calendar['available'].replace(['t','f'],[1,0],inplace=True)
calendar['price']=pd.to_numeric(calendar['price'].str[1:-3].str.replace(',',''))

# %%
#Calculate average price and availability by month
data=calendar.groupby('month').agg('mean')[['available','price']]

# %%
#Plot timeseries
fig, ax1 = plt.subplots(figsize=(16,8))

color = 'tab:blue'
line1=ax1.plot(data['available'], color=color, label='available (left)')

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:red'
line2=ax2.plot(data['price'], color=color, label='price')

#format axis
ax1.set_xlabel('month')
ax1.set_ylabel('Average availability')
ax2.set_ylabel('Average price per night')
ax1.yaxis.set_major_formatter(PercentFormatter(xmax=1))
plt.xticks(range(1,13),['January', 'February', 'March', 'April', 'May', 'June',
                     'July', 'August', 'September', 'October', 'November', 'December'])

#format legend
lns = line1+line2
labs = [l.get_label() for l in lns]
ax1.legend(lns, labs, loc=0)

fig.tight_layout()
plt.title('Seasonality of price and availability of Airbnb 2016 listings in Seattle')
plt.savefig('02_price_seasonality.jpg',dpi=100)
plt.show()

# %% [markdown]
# ## 3) Build a forecast model to predict listing price per night

# %% [markdown]
# What if you wanted to offer your own Seattle appartment at Airbnb? How much would you be able to earn per night?
# We build a OLS model to see what drives listing prices and to predict what we can hope to earn.

# %%
#Import dataset
df=pd.read_csv('listings.csv')

# %%
#Drop all features with more than 75% missing
df=df[df.columns[~(df.isnull().sum()/df.shape[0]>.75)]]

# %%
#Drop missing prices and convert to numeric
df['price']=pd.to_numeric(df['price'].str[1:-3].str.replace(',',''))
df = df.dropna(subset=['price'], axis=0)

# %%
#Create dependent variable
y = df['price']

# %%
#Drop all categorical vars with more than 20 unique values or less than 2. 
#This way we get rid of 'non-sensical' columns, like listing_url, that likely will not explain price.

all_cat_cols=df.select_dtypes(include=['object']).columns
drop_cat_cols=all_cat_cols[(df[all_cat_cols].nunique()<=1)|(df[all_cat_cols].nunique()>20)].values
df=df.drop(drop_cat_cols,axis=1)

# %%
#Drop additional column with limited information value (ids), no variability (city, state = Seattle, WA),
#or columns that are perfectly correlated with other explanatory features ('host_total_listings_count').

drop_other_cols=['price','id', 'scrape_id', 'host_id', 'host_total_listings_count',
                 'calculated_host_listings_count','state','city','smart_location']
df=df.drop(drop_other_cols,axis=1)

# %%
#Convert to categorical columns to dummies and drop
cat_cols=df.select_dtypes(include=['object']).columns
for var in cat_cols:
    # for each cat add dummy var, drop original column
    df = pd.concat([df.drop(var, axis=1), pd.get_dummies(df[var], prefix=var, prefix_sep='_', drop_first=True)], axis=1)

# %%
#Fill missing numeric values with the mean
num_vars = df.select_dtypes(include=['float64', 'int64']).columns
for col in num_vars:
    df[col].fillna((df[col].mean()), inplace=True)

# %% [markdown]
# Now that we have prepared the data, we can train our model.

# %%
#Create explanatory variables
X=df

#Split dataset in train and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .2, random_state=42)

#Instatiate and train model
lm_model = OLS(y_train,X_train).fit()

#Print model results
lm_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  price   R-squared (uncentered):                   0.869
# Model:                            OLS   Adj. R-squared (uncentered):              0.866
# Method:                 Least Squares   F-statistic:                              271.0
# Date:                Sat, 21 Mar 2020   Prob (F-statistic):                        0.00
# Time:                        14:00:14   Log-Likelihood:                         -16670.
# No. Observations:                3054   AIC:                                  3.349e+04
# Df Residuals:                    2981   BIC:                                  3.393e+04
# Df Model:                          73
# Covariance Type:            nonrobust
# ====================================================================================================================
#                                                        coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------
# host_listings_count                                  0.0264      0.038      0.703      0.482      -0.047       0.100
# latitude                                          -127.4408     74.698     -1.706      0.088    -273.906      19.024
# longitude                                          -49.4022     29.102     -1.698      0.090    -106.465       7.660
# accommodates                                         8.2421      1.305      6.314      0.000       5.683      10.802
# bathrooms                                           26.1460      2.432     10.752      0.000      21.378      30.914
# bedrooms                                            29.1442      2.255     12.926      0.000      24.723      33.565
# beds                                                 1.8662      1.996      0.935      0.350      -2.048       5.781
# guests_included                                      3.8018      1.008      3.770      0.000       1.824       5.779
# minimum_nights                                      -0.0080      0.058     -0.139      0.890      -0.121       0.105
# maximum_nights                                      -0.0007      0.001     -1.295      0.195      -0.002       0.000
# availability_30                                      0.0468      0.279      0.168      0.867      -0.500       0.594
# availability_60                                     -0.0012      0.312     -0.004      0.997      -0.613       0.611
# availability_90                                      0.0670      0.163      0.412      0.680      -0.252       0.386
# availability_365                                     0.0257      0.011      2.360      0.018       0.004       0.047
# number_of_reviews                                   -0.0675      0.036     -1.879      0.060      -0.138       0.003
# review_scores_rating                                 0.6568      0.302      2.174      0.030       0.065       1.249
# review_scores_accuracy                               3.1669      2.272      1.394      0.163      -1.288       7.621
# review_scores_cleanliness                            2.6012      1.958      1.328      0.184      -1.238       6.441
# review_scores_checkin                               -1.4581      2.802     -0.520      0.603      -6.952       4.036
# review_scores_communication                         -0.5114      3.060     -0.167      0.867      -6.512       5.489
# review_scores_location                               3.5404      2.169      1.632      0.103      -0.713       7.794
# review_scores_value                                 -6.9118      2.284     -3.026      0.002     -11.391      -2.433
# reviews_per_month                                   -2.4807      0.856     -2.898      0.004      -4.159      -0.802
# host_response_time_within a day                     -5.1635      4.778     -1.081      0.280     -14.532       4.206
# host_response_time_within a few hours                2.8943      4.776      0.606      0.545      -6.471      12.260
# host_response_time_within an hour                  -10.6925      4.754     -2.249      0.025     -20.014      -1.371
# host_acceptance_rate_100%                          -28.3690      3.958     -7.168      0.000     -36.129     -20.608
# host_is_superhost_t                                 12.7731      2.926      4.365      0.000       7.035      18.511
# host_has_profile_pic_t                              12.3006     26.034      0.472      0.637     -38.746      63.347
# host_identity_verified_t                             0.5689      2.643      0.215      0.830      -4.613       5.751
# neighbourhood_group_cleansed_Beacon Hill           -19.3139      9.389     -2.057      0.040     -37.723      -0.905
# neighbourhood_group_cleansed_Capitol Hill           22.5859      5.488      4.115      0.000      11.825      33.347
# neighbourhood_group_cleansed_Cascade                28.3144      8.486      3.337      0.001      11.676      44.953
# neighbourhood_group_cleansed_Central Area           -3.1220      6.041     -0.517      0.605     -14.967       8.722
# neighbourhood_group_cleansed_Delridge              -36.6842     12.389     -2.961      0.003     -60.976     -12.392
# neighbourhood_group_cleansed_Downtown               36.1649      6.441      5.615      0.000      23.536      48.794
# neighbourhood_group_cleansed_Interbay              -18.3726     21.348     -0.861      0.390     -60.231      23.486
# neighbourhood_group_cleansed_Lake City              -9.1227     10.257     -0.889      0.374     -29.233      10.988
# neighbourhood_group_cleansed_Magnolia               14.6214      9.624      1.519      0.129      -4.250      33.493
# neighbourhood_group_cleansed_Northgate             -19.6278      9.654     -2.033      0.042     -38.556      -0.699
# neighbourhood_group_cleansed_Other neighborhoods    -1.1195      4.984     -0.225      0.822     -10.893       8.654
# neighbourhood_group_cleansed_Queen Anne             24.8190      6.219      3.991      0.000      12.624      37.014
# neighbourhood_group_cleansed_Rainier Valley        -22.7399      9.189     -2.475      0.013     -40.757      -4.722
# neighbourhood_group_cleansed_Seward Park           -17.8101     11.814     -1.508      0.132     -40.974       5.354
# neighbourhood_group_cleansed_University District    -4.5363      7.528     -0.603      0.547     -19.296      10.224
# neighbourhood_group_cleansed_West Seattle          -11.5149     10.783     -1.068      0.286     -32.657       9.627
# is_location_exact_t                                  1.1050      3.495      0.316      0.752      -5.748       7.958
# property_type_Bed & Breakfast                       17.3896     11.266      1.544      0.123      -4.700      39.479
# property_type_Boat                                 164.6992     26.709      6.166      0.000     112.329     217.070
# property_type_Bungalow                              14.4049     17.597      0.819      0.413     -20.099      48.909
# property_type_Cabin                                 19.7965     14.376      1.377      0.169      -8.391      47.984
# property_type_Camper/RV                             57.9485     20.639      2.808      0.005      17.481      98.416
# property_type_Chalet                                21.8633     59.620      0.367      0.714     -95.037     138.764
# property_type_Condominium                            5.5303      6.933      0.798      0.425      -8.063      19.124
# property_type_Dorm                                 -60.9140     59.211     -1.029      0.304    -177.013      55.185
# property_type_House                                  7.8714      2.934      2.683      0.007       2.118      13.625
# property_type_Loft                                  30.9064      9.886      3.126      0.002      11.522      50.291
# property_type_Other                                 -4.7910     14.226     -0.337      0.736     -32.685      23.103
# property_type_Tent                                 -21.7221     27.285     -0.796      0.426     -75.222      31.778
# property_type_Townhouse                              3.9841      6.455      0.617      0.537      -8.673      16.641
# property_type_Treehouse                             14.4375     33.514      0.431      0.667     -51.276      80.151
# property_type_Yurt                                  26.5086     57.928      0.458      0.647     -87.075     140.092
# room_type_Private room                             -35.9742      3.047    -11.805      0.000     -41.949     -29.999
# room_type_Shared room                              -62.3832      7.041     -8.860      0.000     -76.189     -48.577
# bed_type_Couch                                     -15.7746     23.007     -0.686      0.493     -60.885      29.336
# bed_type_Futon                                     -19.2371     15.149     -1.270      0.204     -48.941      10.467
# bed_type_Pull-out Sofa                             -16.3188     16.118     -1.012      0.311     -47.923      15.285
# bed_type_Real Bed                                  -11.0953     13.033     -0.851      0.395     -36.650      14.459
# instant_bookable_t                                   2.8297      3.158      0.896      0.370      -3.363       9.022
# cancellation_policy_moderate                        -3.9844      2.779     -1.434      0.152      -9.434       1.465
# cancellation_policy_strict                           0.6628      2.934      0.226      0.821      -5.091       6.416
# require_guest_profile_picture_t                      7.2154      7.798      0.925      0.355      -8.075      22.506
# require_guest_phone_verification_t                  -5.1106      7.324     -0.698      0.485     -19.472       9.250
# ==============================================================================
# Omnibus:                     2820.947   Durbin-Watson:                   1.974
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           268717.573
# Skew:                           4.041   Prob(JB):                         0.00
# Kurtosis:                      48.237   Cond. No.                     1.61e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.61e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# The model yields a relatively high adjusted R-squared of 87%. We find a lot features that have a materially siginficant impact on the listing price. However, not all of them are statistically significant. We only want to see features where we can be very certain that the coefficient is not a random result but actually robust and reliable. To do that, we filter out only coefficients of feautres with p-value < 1%.

# %%
#Store model results in dataframe
results=pd.DataFrame()
results['coefficient']=lm_model.params
results['abs_coefficient']=np.abs(lm_model.params)
results['p_value']=lm_model.pvalues

# %%
#Filter for features wit p<1% and print sorted list
sig_vars=results[results['p_value']<.01].sort_values('abs_coefficient',ascending=False).index
results[results['p_value']<.01].sort_values('abs_coefficient',ascending=False)
# Out:
#                                            coefficient  abs_coefficient  \
# property_type_Boat                          164.699200       164.699200
# room_type_Shared room                       -62.383211        62.383211
# property_type_Camper/RV                      57.948526        57.948526
# neighbourhood_group_cleansed_Delridge       -36.684180        36.684180
# neighbourhood_group_cleansed_Downtown        36.164910        36.164910
# room_type_Private room                      -35.974165        35.974165
# property_type_Loft                           30.906426        30.906426
# bedrooms                                     29.144211        29.144211
# host_acceptance_rate_100%                   -28.368978        28.368978
# neighbourhood_group_cleansed_Cascade         28.314374        28.314374
# bathrooms                                    26.146035        26.146035
# neighbourhood_group_cleansed_Queen Anne      24.819035        24.819035
# neighbourhood_group_cleansed_Capitol Hill    22.585903        22.585903
# host_is_superhost_t                          12.773101        12.773101
# accommodates                                  8.242056         8.242056
# property_type_House                           7.871351         7.871351
# review_scores_value                          -6.911847         6.911847
# guests_included                               3.801751         3.801751
# reviews_per_month                            -2.480708         2.480708
#
#                                                 p_value
# property_type_Boat                         7.930179e-10
# room_type_Shared room                      1.347630e-18
# property_type_Camper/RV                    5.021101e-03
# neighbourhood_group_cleansed_Delridge      3.090753e-03
# neighbourhood_group_cleansed_Downtown      2.146185e-08
# room_type_Private room                     1.828579e-31
# property_type_Loft                         1.787568e-03
# bedrooms                                   3.154780e-37
# host_acceptance_rate_100%                  9.575336e-13
# neighbourhood_group_cleansed_Cascade       8.583386e-04
# bathrooms                                  1.766953e-26
# neighbourhood_group_cleansed_Queen Anne    6.748165e-05
# neighbourhood_group_cleansed_Capitol Hill  3.971836e-05
# host_is_superhost_t                        1.315126e-05
# accommodates                               3.122917e-10
# property_type_House                        7.346783e-03
# review_scores_value                        2.499365e-03
# guests_included                            1.664401e-04
# reviews_per_month                          3.788024e-03

# %% [markdown]
# We will retrain the model with only statistically significant features.

# %%
#Create explanatory variables (only stat. signifcant)
X=df[sig_vars]

#Split dataset in train and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .2, random_state=42)

#Instatiate and train model
lm_model = OLS(y_train,X_train).fit()

#Evaluate model fit on test set
y_hat=lm_model.predict(X_test)
r2=r2_score(y_test,y_hat)

print("The R-squared of the model prediction on the test set is: {:.1%}".format(r2))
# Out:
# The R-squared of the model prediction on the test set is: 58.0%
